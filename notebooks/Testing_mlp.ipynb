# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Generate training data using ILQR

# %%
from generate_data import gen_uni_training_data, ILQR, unicycle_K, save_object

uni_ilqr1 = ILQR(unicycle_K, maxiter=1000)
num_iter = 1
xtraj, rtraj, rdottraj, costs, dynamics = gen_uni_training_data(uni_ilqr1, num_iter, "/home/anusha/file.pkl", 6, 3)
# Out:
# [[2.54264129 1.0415039 ]]
# [[1.26729647 1.49760777 1.56610597]]

# %% [markdown]
# ## Visualize the data

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()
Tstart = 0
Tend = 10

wp = np.array([1.26729647, 1.49760777])*2/3 + np.array([2.54264129, 1.0415039])/2

plt.plot(rtraj[0][Tstart:Tend, 0], rtraj[0][Tstart:Tend, 1], 'r-', label="ref")
plt.plot(xtraj[0][Tstart:Tend, 0], xtraj[0][Tstart:Tend, 1], 'b-', label="state")
plt.scatter(wp[0], wp[1], label="waypoint")
plt.legend()
